# %% [markdown]
# Data: https://archive.ics.uci.edu/dataset/925/infrared+thermography+temperature+dataset
#
# Instruction: Choose a dataset and perform a data storytelling, choose the proper data visualization, do not use words, your graphs must tell a story.

# %%
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler


columns = [
    'SubjectID', 'aveOralF', 'aveOralM', 'Gender', 'Age', 'Ethnicity',
    'T_atm', 'Humidity', 'Distance', 'T_offset1'
]


url = "FLIR_groups1and2.csv" 
df = pd.read_csv(url, names=columns)


df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
df.info()


df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
missing_values = data.isnull().sum()
print("Missing values in each column:\n", missing_values)
# Out:
# Missing values in each column:
#  SubjectID    0
# aveOralF     0
# aveOralM     0
# Gender       0
# Age          0
# Ethnicity    0
# T_atm        0
# Humidity     0
# Distance     0
# T_offset1    0
# dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['aveOralF'], kde=True)
plt.title('Distribution of Oral Temperature (Fast Mode)')
plt.xlabel('Oral Temperature (Fast Mode)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Gender', data=data)
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Age', data=data)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='T_atm', y='aveOralF', hue='Gender', data=data)
plt.title('Ambient Temperature vs Oral Temperature')
plt.xlabel('Ambient Temperature')
plt.ylabel('Oral Temperature (Fast Mode)')
plt.show()
