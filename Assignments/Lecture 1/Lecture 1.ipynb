# %% [markdown]
# $\textbf{PROGRAMMING ASSIGNMENT}$
# ---
# Name: Curtney Sealtiel Mata Juma-ang
#
# Selected Dataset: https://archive.ics.uci.edu/dataset/158/poker+hand
#
# Instructions: Choose a dataset of your liking and perform the following:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import requests
from io import StringIO\

cols = ["Suit of Card #1", "Rank of card #1", "Suit of card #2", "Rank of card #2", "Suit of card #3", "Rank of card #3", "Suit of card #4", "Rank of card #4", "Suit of card #5", 
       "Rank of card 5", "class"]
df = pd.read_csv("poker-hand-testing.data", names=cols)
df["class"] = (df["class"]== "g").astype(int)

print(df.head())  
print(df.info())
# Out:
#    Suit of Card #1  Rank of card #1  Suit of card #2  Rank of card #2  \
# 0                1                1                1               13
# 1                3               12                3                2
# 2                1                9                4                6
# 3                1                4                3               13
# 4                3               10                2                7
#
#    Suit of card #3  Rank of card #3  Suit of card #4  Rank of card #4  \
# 0                2                4                2                3
# 1                3               11                4                5
# 2                1                4                3                2
# 3                2               13                2                1
# 4                1                2                2               11
#
#    Suit of card #5  Rank of card 5  class
# 0                1              12      0
# 1                2               5      0
# 2                3               9      0
# 3                3               6      0
# 4                4               9      0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   Suit of Card #1  1000000 non-null  int64
#  1   Rank of card #1  1000000 non-null  int64
#  2   Suit of card #2  1000000 non-null  int64
#  3   Rank of card #2  1000000 non-null  int64
#  4   Suit of card #3  1000000 non-null  int64
#  5   Rank of card #3  1000000 non-null  int64
#  6   Suit of card #4  1000000 non-null  int64
#  7   Rank of card #4  1000000 non-null  int64
#  8   Suit of card #5  1000000 non-null  int64
#  9   Rank of card 5   1000000 non-null  int64
#  10  class            1000000 non-null  int32
# dtypes: int32(1), int64(10)
# memory usage: 80.1 MB
# None

# %% [markdown]
# 1. Create a Correlation Plot

# %%
correlation_matrix = df.corr()


plt.figure(figsize=(10, 8))
plt.imshow(correlation_matrix, cmap='coolwarm', interpolation='nearest')
plt.colorbar(label='Correlation')
plt.title('Correlation Plot')
plt.xticks(range(len(correlation_matrix.columns)), correlation_matrix.columns, rotation=90)
plt.yticks(range(len(correlation_matrix.columns)), correlation_matrix.columns)
plt.show()

# %% [markdown]
# 2. Check the distribution of each column and determine which probability distiribution it fits.

# %%
plt.figure(figsize=(15, 10))
for i, col in enumerate(data.columns):
    plt.subplot(3, 4, i + 1)
    sns.histplot(data[col], kde=True)
    plt.title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# 3. Create a summary statistics.

# %%
summary_stats = data.describe()
print(summary_stats)

# %% [markdown]
# 4. Perform a hypothesis test (Code from scratch).

# %%
contingency_table = pd.crosstab(data['S1'], data['Hand'])
chi2, p, dof, expected = chi2_contingency(contingency_table)
print("Chi-square statistic:", chi2)
print("P-value:", p)
